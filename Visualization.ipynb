# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiamchd/Google-Data-Analytics-Certificate/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-88cb9ba1-4db4-47ee-b598-3477b5ce0916" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88cb9ba1-4db4-47ee-b598-3477b5ce0916">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving amount_activity_classification - amount_activity_classification.csv to amount_activity_classification - amount_activity_classification.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['bquxjob_7d751f98_181d305e039.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df.head()

# %%
df.describe()

# %%
df.hist(figsize=(15,15,));

# %%
df.isnull().sum()

# %%
# Substituindo os valores ausentes pela média 

weight_kg_mean = df.WeightKg.mean()
df.WeightKg.fillna(weight_kg_mean,inplace = True)

weight_pounds_mean = df.WeightPounds.mean()
df.WeightPounds.fillna(weight_pounds_mean,inplace = True)

BMI_mean = df.BMI.mean()
df.BMI.fillna(BMI_mean,inplace = True)

# %%
df.isnull().sum()

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

df["WeightKg"].plot(kind="line", ax=ax) 
ax.set_title("Weight change")
ax.set_xlabel("Time")
ax.set_ylabel("Weight")

plt.tight_layout()

# %%
# !pip install https://github.com/ydataai/pandas-profiling/archive/master.zip -q
# Out:
#      \ 21.8 MB 141 kB/s
#      |████████████████████████████████| 596 kB 5.3 MB/s
#      |████████████████████████████████| 102 kB 59.3 MB/s
#      |████████████████████████████████| 690 kB 52.9 MB/s
#      |████████████████████████████████| 4.7 MB 46.7 MB/s
#      |████████████████████████████████| 62 kB 1.2 MB/s
#      |████████████████████████████████| 812 kB 38.8 MB/s
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['dailyActivity_merged.csv']))

# %%
from pandas_profiling import ProfileReport

# %%
report = ProfileReport(df)

# %%
report.to_file("report.html")

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['amount_activity_classification - amount_activity_classification.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df.head()
# Out:
#   use_classification  amount_users
# 0           High Use            29
# 1       Moderate Use             3
# 2       Very Low Use             2

# %%
fig, ax = plt.subplots()

plt.barh(df['use_classification'], df['amount_users'])

ax.set_title("Adherence of user in tracking daily activities")
ax.set_xlabel("Users")


plt.tight_layout()

# %% [markdown]
# # 4.1.4 - Adherence of users in tracking their daily activities + sleep + weight

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ab5d54c-bc18-4ccf-bef3-35dd14956dcc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ab5d54c-bc18-4ccf-bef3-35dd14956dcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dailyActivity_sleep_weight_classification.csv to dailyActivity_sleep_weight_classification.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['dailyActivity_sleep_weight_classification.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df.head()

# %%
fig, ax = plt.subplots()

plt.barh(df['use_classification'], df['amount_users'])

ax.set_title("Adherence of user in tracking daily activities")
ax.set_xlabel("Users")


plt.tight_layout()

# %%
df.plot(x='use_classification', 
        kind='bar', 
        stacked=False,
        figsize = (10,6),
        width = 1, edgecolor = 'white',
        color = ("#EF957D", "#D96E66", "#F87596"),
        title='Adherence of users in tracking their activities',
        xlabel = '',
        ylabel = 'Use in 31 days (%)') 


plt.tight_layout()

# %% [markdown]
# ## 4.1.7 - Average of device usage per day through time

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-10581ae9-7298-492f-bb59-9527903174aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10581ae9-7298-492f-bb59-9527903174aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving usingTime_avg_perDay - Sheet1.csv to usingTime_avg_perDay - Sheet1.csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['usingTime_avg_perDay - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df2.head()
# Out:
#          date  avg_hour_per_day
# 0  2016-04-12             24.00
# 1  2016-04-13             24.00
# 2  2016-04-14             24.00
# 3  2016-04-15             23.76
# 4  2016-04-16             24.00

# %%
fig, ax = plt.subplots()

df2["avg_hour_per_day"].plot(kind="line", color = ("#EF957D") ,ax=ax) 
ax.set_title("Average of device usage per day through time")
ax.set_xlabel("Days")
ax.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# O uso do aparelho se mantém bem perto das 24 horas, tendo algumas variações no caminho, provavelmente pela interrupção do uso de poucos usuários. Porém há uma queda bruca no último dia dos dados disponíveisl. Isso levanta algumas questões: 1. O uso pode ter caído apenas porque não foi disponibilizado mais dados; 2. É um tempo médio de duração da bateria, sendo nesse dia necessário a retirada do aparelho para carregar

# %% [markdown]
# # 4.1.8 - Digging into low adherence users

# %% [markdown]
# ## User 2347167796

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b44ea64-fdf6-4820-a7e4-0572617c8788" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b44ea64-fdf6-4820-a7e4-0572617c8788">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lowAdherence_2347167796 - Sheet1.csv to lowAdherence_2347167796 - Sheet1.csv

# %%
import io
df1 = pd.read_csv(io.BytesIO(uploaded['lowAdherence_2347167796 - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df1.head()
# Out:
#            Id        date  hour_per_day
# 0  2347167796  2016-04-12            24
# 1  2347167796  2016-04-13            24
# 2  2347167796  2016-04-14            24
# 3  2347167796  2016-04-15            24
# 4  2347167796  2016-04-16            24

# %%
fig, ax = plt.subplots()

df1["hour_per_day"].plot(kind="line",xlim = [0,30], ax=ax) 
ax.set_title("Average of device usage per day through time")
ax.set_xlabel("Days")
ax.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# ## User 3372868164

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d413e421-9df1-40eb-9625-5832d70df80c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d413e421-9df1-40eb-9625-5832d70df80c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lowAdherence_3372868164 - Sheet1.csv to lowAdherence_3372868164 - Sheet1.csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['lowAdherence_3372868164 - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df2.head()
# Out:
#            Id        date  hour_per_day
# 0  3372868164  2016-04-12            24
# 1  3372868164  2016-04-13            24
# 2  3372868164  2016-04-14            24
# 3  3372868164  2016-04-15            24
# 4  3372868164  2016-04-16            24

# %%
fig, ax = plt.subplots()

df2["hour_per_day"].plot(kind="line",xlim = [0,30], ax=ax) 
ax.set_title("Average of device usage per day through time")
ax.set_xlabel("Days")
ax.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# ## User 4057192912

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd50e85c-97ea-4ee3-a0ae-7070a5e88c02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd50e85c-97ea-4ee3-a0ae-7070a5e88c02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lowAdherence_4057192912 - Sheet1.csv to lowAdherence_4057192912 - Sheet1.csv

# %%
import io
df3 = pd.read_csv(io.BytesIO(uploaded['lowAdherence_4057192912 - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df3.head()
# Out:
#            Id        date  hour_per_day
# 0  4057192912  2016-04-12            24
# 1  4057192912  2016-04-13            24
# 2  4057192912  2016-04-14            24
# 3  4057192912  2016-04-15            16

# %%
fig, ax = plt.subplots()

df3["hour_per_day"].plot(kind="line",xlim = [0,30] , ax=ax) 
ax.set_title("Average of device usage per day through time")
ax.set_xlabel("Days")
ax.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# ## User 6117666160

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c1b4022-f638-44d3-8fbc-6e864169bfbf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c1b4022-f638-44d3-8fbc-6e864169bfbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lowAdherence_6117666160 - Sheet1.csv to lowAdherence_6117666160 - Sheet1.csv

# %%
import io
df4 = pd.read_csv(io.BytesIO(uploaded['lowAdherence_6117666160 - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
fig, ax = plt.subplots()

df4["hour_per_day"].plot(kind="line",xlim = [0,30] , ax=ax) 
ax.set_title("Average of device usage per day through time")
ax.set_xlabel("Days")
ax.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# ## User 6290855005

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1f9d8319-9a29-4461-932a-44d44f3b831e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f9d8319-9a29-4461-932a-44d44f3b831e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lowAdherence_6290855005 - Sheet1.csv to lowAdherence_6290855005 - Sheet1.csv

# %%
import io
df5 = pd.read_csv(io.BytesIO(uploaded['lowAdherence_6290855005 - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
fig, ax = plt.subplots()

df5["hour_per_day"].plot(kind="line",xlim = [0,30] , ax=ax) 
ax.set_title("Average of device usage per day through time")
ax.set_xlabel("Days")
ax.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# ## User 7007744171

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-80bf9f72-2285-4a5c-9503-185903fd6879" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80bf9f72-2285-4a5c-9503-185903fd6879">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lowAdherence_7007744171 - Sheet1.csv to lowAdherence_7007744171 - Sheet1.csv

# %%
import io
df6 = pd.read_csv(io.BytesIO(uploaded['lowAdherence_7007744171 - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
fig, ax = plt.subplots()

df6["hour_per_day"].plot(kind="line",xlim = [0,30] , ax=ax) 
ax.set_title("Average of device usage per day through time")
ax.set_xlabel("Days")
ax.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# ## User 8253242879

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d03660d8-7053-41df-b3f7-361302e9bdbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d03660d8-7053-41df-b3f7-361302e9bdbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lowAdherence_8253242879 - Sheet1.csv to lowAdherence_8253242879 - Sheet1.csv

# %%
import io
df7 = pd.read_csv(io.BytesIO(uploaded['lowAdherence_8253242879 - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
fig, ax = plt.subplots()

df7["hour_per_day"].plot(kind="line",xlim = [0,30] , ax=ax) 
ax.set_title("Average of device usage per day through time")
ax.set_xlabel("Days")
ax.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# ## Joining 7 Users

# %%
# plotar o histograma da temperatura média
# fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,4))  # ax[0] e ax[1]
fig, (ax1, ax2,ax3,ax4,ax5,ax6,ax7) = plt.subplots(nrows=7, ncols=1, figsize=(10,15))

# User 2347167796
df1["hour_per_day"].plot(kind="line",xlim = [0,30],ylim = [15,30], color = ("#EF957D") , ax=ax1) 
ax1.set_title("User 1: Average of device usage per day through days")
ax1.set_xlabel("Days")
ax1.set_ylabel("Hours per day")

# User 3372868164
df2["hour_per_day"].plot(kind="line",xlim = [0,30],ylim = [15,30], color = ("#EF957D") , ax=ax2) 
ax2.set_title("User 2: Average of device usage per day through days")
ax2.set_xlabel("Days")
ax2.set_ylabel("Hours per day")

# User 4057192912
df3["hour_per_day"].plot(kind="line",xlim = [0,30] ,ylim = [15,30], color = ("#EF957D") , ax=ax3) 
ax3.set_title("Average of device usage per day through time")
ax3.set_xlabel("Days")
ax3.set_ylabel("Hours per day")

# User 6117666160
df4["hour_per_day"].plot(kind="line",xlim = [0,30] ,ylim = [15,30], color = ("#EF957D") , ax=ax4) 
ax4.set_title("User 4: Average of device usage per day through days")
ax4.set_xlabel("Days")
ax4.set_ylabel("Hours per day")

# User 6290855005
df5["hour_per_day"].plot(kind="line",xlim = [0,30] ,ylim = [15,30], color = ("#EF957D") , ax=ax5) 
ax5.set_title("User 5: Average of device usage per day through days")
ax5.set_xlabel("Days")
ax5.set_ylabel("Hours per day")

# User 7007744171
df6["hour_per_day"].plot(kind="line",xlim = [0,30] ,ylim = [15,30], color = ("#EF957D") , ax=ax6) 
ax6.set_title("User 6: Average of device usage per day through days")
ax6.set_xlabel("Days")
ax6.set_ylabel("Hours per day")

# User 8253242879
df7["hour_per_day"].plot(kind="line",xlim = [0,30] ,ylim = [15,30], color = ("#EF957D") , ax=ax7) 
ax7.set_title("User 7: Average of device usage per day through days")
ax7.set_xlabel("Days")
ax7.set_ylabel("Hours per day")

plt.tight_layout()

# %% [markdown]
# # 4.2 - Understand the users habits

# %% [markdown]
# ## 4.2.1 - Steps classification

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6acaadde-dc7c-4897-a3bc-a93d395398af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6acaadde-dc7c-4897-a3bc-a93d395398af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving steps_classification - Sheet1.csv to steps_classification - Sheet1 (2).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['steps_classification - Sheet1.csv']), index_col='steps_classification')
# Dataset is now stored in a Pandas Dataframe

# %%
# !pip install pywaffle -q

# %%
from pywaffle import Waffle

# %%
df.head()
# Out:
#                       percentage_stepsClassification
# steps_classification
# Somewhat Active                                30.30
# Low Active                                     27.27
# Sedentary                                      21.21
# Active                                         12.12
# Highly Active                                   9.09

# %%
data = df.percentage_stepsClassification.to_dict()

# plotar gráfico de waffle
fig = plt.figure(
                FigureClass=Waffle,
                rows=7,
                columns=20,
                colors=("#EF957D", "#D96E66", "#F87596", "#D99066", "#F8B875"),
                values=data, icons='child', icon_size=25,
                legend={'loc': 'upper left', 'bbox_to_anchor': (1,1)},
                icon_legend=True,
                figsize = (10,6)
                )
fig.set_tight_layout(False)
plt.show();
# Out:
# <Waffle size 720x432 with 1 Axes>

# %% [markdown]
# ## 4.2.2 - Amount of users that achieved the minimum physical activity recommended by the American Heart Association

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ea6b764-4a99-48e3-bea3-1003d13857f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ea6b764-4a99-48e3-bea3-1003d13857f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weekly_minimun_physicalActivity - Sheet1.csv to weekly_minimun_physicalActivity - Sheet1 (2).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['weekly_minimun_physicalActivity - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df.head()
# Out:
#    week  users_remaining  recommendation_achieved  \
# 0    15               33                       15
# 1    16               32                       19
# 2    17               32                       20
# 3    18               30                       15
# 4    19               27                       14
#
#    percentage_recommedationAchieved
# 0                             45.45
# 1                             59.38
# 2                             62.50
# 3                             50.00
# 4                             51.85

# %%
# plotar o gráfico de barras com a entrada média de passageiros
y = [23.3 ,23.3,23.3,23.3,23.3]
x = [0,1,2,3,4]

fig, ax = plt.subplots(figsize = (10,6))

df["percentage_recommedationAchieved"].plot.area(ylim = [0,100], color = "#EF957D" , ax=ax)

                                                 
mean_line = ax.plot(x,y, label='Mean in general population', linestyle='--', color = "black")
ax.set_title("Amount of users that achieved the minimun physical activity recommended by the AHA ")
ax.set_ylabel("Percentage of Users")
ax.set_xlabel("Weeks")
legend = ax.legend(loc='upper right')

plt.tight_layout()

# %% [markdown]
# ## 4.2.7 - The difference in calories spent betweens periods of the day and day of week

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f03f09c1-4dce-441b-97a0-3c8bb67b1c0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f03f09c1-4dce-441b-97a0-3c8bb67b1c0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wide_calories_weekday_period - Sheet1.csv to wide_calories_weekday_period - Sheet1.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['wide_calories_weekday_period - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df.head()
# Out:
#   day_of_week  Dawn  Morning  Afternoon  Night
# 0      Sunday    70       97        114     96
# 1      Monday    72      104        112    101
# 2     Tuesday    73      103        115    103
# 3   Wednesday    71      100        115    102
# 4    Thursday    71      103        115    101

# %%
df.plot(x='day_of_week', 
        kind='bar', 
        stacked=True,
        figsize = (10,6),
        width = 1, edgecolor = 'white',
        title='Calories spent through period of weekday ',
        color = ("#F8B875", "#D96E66", "#F87596", "#D99066"),
        xlabel = 'Weekday',
        ylabel = 'Average calories') 


plt.tight_layout()

# %% [markdown]
# ## 4.2.8 - The difference in steps betweens periods of the day and day of week

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-222b33e7-689b-499a-be2b-a258a6892ac9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-222b33e7-689b-499a-be2b-a258a6892ac9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving steps_weekday_period - Sheet1.csv to steps_weekday_period - Sheet1 (1).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['steps_weekday_period - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df.head()
# Out:
#   day_of_week  Dawn  Morning  Afternoon  Night
# 0      Sunday    35      336        488    294
# 1      Monday    19      414        481    378
# 2     Tuesday    29      394        523    392
# 3   Wednesday    19      354        519    371
# 4    Thursday    21      404        517    369

# %%
df.plot(x='day_of_week', 
        kind='bar', 
        stacked=True,
        figsize = (10,6),
        width = 1, edgecolor = 'white',
        color = ("#F8B875", "#D96E66", "#F87596", "#D99066"),
        title='Steps amount through period of weekday ',
        xlabel = 'Weekday',
        ylabel = 'Average steps') 


plt.tight_layout()
